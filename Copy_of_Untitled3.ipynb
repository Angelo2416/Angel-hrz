# %% [markdown]
# <a href="https://colab.research.google.com/github/Angelo2416/Angel-hrz/blob/main/Copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt


alto = 511
ancho = 511
f_min = 0.004
f_max = 0.45
amplitud_superior = 0.002

# x
x = np.arange(ancho)
# y
y = np.linspace(0, 1, alto)
X, Y = np.meshgrid(x, y)

k3 = np.log(f_max / f_min) / (ancho - 1)
frecuencia = f_min * np.exp(k3 * X)
fase = (
    2 * np.pi * f_min / k
    * (np.exp(k * X) - 1)
)

a = -np.log(amplitud_superior)
amplitud = np.exp(-a * Y)
imagen = amplitud * np.sin(fase)
#imagen = amplitud * np.sin(fase - np.pi/2)
#image_normalized = (imagen - numpy.min(imagen)) / (numpy.max(imagen) - numpy.min(imagen))
plt.figure(figsize=(6, 6))
plt.imshow(imagen, cmap="Greys",origin="lower")
#plt.axis("off")
#plt.tight_layout()
plt.title("Imagen con Señal Senoidal y Atenuación")
plt.savefig('sine_image.png')

plt.show()
